# %%
import pandas as pd

# %%
fund = pd.read_csv("fundamentals.csv")
fund.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %%
fund1 = pd.read_csv("fundamentals.csv",index_col="Ticker Symbol")
fund1.head()
# Out:
#                Unnamed: 0 Period Ending  Accounts Payable  \
# Ticker Symbol
# AAL                     0    2012-12-31      3.068000e+09
# AAL                     1    2013-12-31      4.975000e+09
# AAL                     2    2014-12-31      4.668000e+09
# AAL                     3    2015-12-31      5.102000e+09
# AAP                     4    2012-12-29      2.409453e+09
#
#                Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# Ticker Symbol
# AAL                   -222000000.0               -1.961000e+09           23.0
# AAL                    -93000000.0               -2.723000e+09           67.0
# AAL                   -160000000.0               -1.500000e+08          143.0
# AAL                    352000000.0               -7.080000e+08          135.0
# AAP                    -89482000.0                6.000000e+05           32.0
#
#                Capital Expenditures  Capital Surplus  Cash Ratio  \
# Ticker Symbol
# ...

# %%
print (fund.columns)
# Out:
# Index(['Unnamed: 0', 'Ticker Symbol', 'Period Ending', 'Accounts Payable',
#        'Accounts Receivable', 'Add'l income/expense items', 'After Tax ROE',
#        'Capital Expenditures', 'Capital Surplus', 'Cash Ratio',
#        'Cash and Cash Equivalents', 'Changes in Inventories', 'Common Stocks',
#        'Cost of Revenue', 'Current Ratio', 'Deferred Asset Charges',
#        'Deferred Liability Charges', 'Depreciation',
#        'Earnings Before Interest and Tax', 'Earnings Before Tax',
#        'Effect of Exchange Rate',
#        'Equity Earnings/Loss Unconsolidated Subsidiary', 'Fixed Assets',
#        'Goodwill', 'Gross Margin', 'Gross Profit', 'Income Tax',
#        'Intangible Assets', 'Interest Expense', 'Inventory', 'Investments',
#        'Liabilities', 'Long-Term Debt', 'Long-Term Investments',
#        'Minority Interest', 'Misc. Stocks', 'Net Borrowings', 'Net Cash Flow',
#        'Net Cash Flow-Operating', 'Net Cash Flows-Financing',
# ...

# %%
fund[['Ticker Symbol','Total Revenue','Earnings Before Tax']]
# Out:
#      Ticker Symbol  Total Revenue  Earnings Before Tax
# 0              AAL   2.485500e+10        -2.445000e+09
# 1              AAL   2.674300e+10        -2.180000e+09
# 2              AAL   4.265000e+10         3.212000e+09
# 3              AAL   4.099000e+10         4.616000e+09
# 4              AAP   6.205003e+09         6.240740e+08
# ...            ...            ...                  ...
# 1776          ZION   2.210591e+09         4.518590e+08
# 1777           ZTS   4.561000e+09         6.900000e+08
# 1778           ZTS   4.785000e+09         8.200000e+08
# 1779           ZTS   4.765000e+09         5.450000e+08
# 1780           ZTS   4.888000e+09         1.228000e+09
#
# [1781 rows x 3 columns]

# %%
aapl = fund1.loc[["AAPL"]]

# %%
aapl.columns
# Out:
# Index(['Unnamed: 0', 'Period Ending', 'Accounts Payable',
#        'Accounts Receivable', 'Add'l income/expense items', 'After Tax ROE',
#        'Capital Expenditures', 'Capital Surplus', 'Cash Ratio',
#        'Cash and Cash Equivalents', 'Changes in Inventories', 'Common Stocks',
#        'Cost of Revenue', 'Current Ratio', 'Deferred Asset Charges',
#        'Deferred Liability Charges', 'Depreciation',
#        'Earnings Before Interest and Tax', 'Earnings Before Tax',
#        'Effect of Exchange Rate',
#        'Equity Earnings/Loss Unconsolidated Subsidiary', 'Fixed Assets',
#        'Goodwill', 'Gross Margin', 'Gross Profit', 'Income Tax',
#        'Intangible Assets', 'Interest Expense', 'Inventory', 'Investments',
#        'Liabilities', 'Long-Term Debt', 'Long-Term Investments',
#        'Minority Interest', 'Misc. Stocks', 'Net Borrowings', 'Net Cash Flow',
#        'Net Cash Flow-Operating', 'Net Cash Flows-Financing',
# ...

# %%
aapl[['Earnings Before Tax','Total Equity']]
# Out:
#                Earnings Before Tax  Total Equity
# Ticker Symbol
# AAPL                  5.015500e+10  1.235490e+11
# AAPL                  5.348300e+10  1.115470e+11
# AAPL                  7.251500e+10  1.193550e+11
# AAPL                  6.137200e+10  1.282490e+11

# %%
fund1['Earnings Per Share'].nsmallest(10)
# Out:
# Ticker Symbol
# APA   -61.20
# DVN   -35.55
# XEC   -25.92
# CHK   -22.43
# NFX   -21.18
# APA   -14.06
# APC   -13.18
# MUR   -13.03
# FCX   -11.31
# AAL   -11.25
# Name: Earnings Per Share, dtype: float64

# %%
fund1['Total Revenue'] = fund1['Total Revenue'].astype('int')

# %%
fund1[fund1['Total Revenue']<1000000000]
# Out:
#                Unnamed: 0 Period Ending  Accounts Payable  \
# Ticker Symbol
# AAL                     0    2012-12-31      3.068000e+09
# AAL                     1    2013-12-31      4.975000e+09
# AAL                     2    2014-12-31      4.668000e+09
# AAL                     3    2015-12-31      5.102000e+09
# AAP                     4    2012-12-29      2.409453e+09
# ...                   ...           ...               ...
# ZION                 1776    2015-12-31      0.000000e+00
# ZTS                  1777    2013-12-31      1.381000e+09
# ZTS                  1778    2014-12-31      1.071000e+09
# ZTS                  1779    2015-12-31      1.313000e+09
# ZTS                  1780    2016-12-31      1.076000e+09
#
#                Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# Ticker Symbol
# AAL                   -222000000.0               -1.961000e+09           23.0
# AAL                    -93000000.0               -2.723000e+09           67.0
# ...

# %%
fund1[fund1['Total Revenue']>=1000000000]
fund1[(fund1['Total Revenue']>=1000000000) &(fund1['Total Revenue']<=10000000000)]
# Out:
#                Unnamed: 0 Period Ending  Accounts Payable  \
# Ticker Symbol
# AKAM                   72    2012-12-31       176378000.0
# AKAM                   73    2013-12-31       224095000.0
# AKAM                   74    2014-12-31       282098000.0
# ALLE                   88    2013-12-31       418500000.0
# ALLE                   89    2014-12-31       379400000.0
# ...                   ...           ...               ...
# WAT                  1672    2014-12-31       141311000.0
# WAT                  1673    2015-12-31       153469000.0
# XEC                  1729    2012-12-31       630377000.0
# XEC                  1730    2013-12-31       647586000.0
# XEC                  1732    2015-12-31       396636000.0
#
#                Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# Ticker Symbol
# AKAM                    -2108000.0                   7104000.0            9.0
# AKAM                   -67184000.0                   5586000.0           11.0
# ...

# %%
fund1['Total Revenue'].nlargest(10)
# Out:
# Ticker Symbol
# MCHP    2147036000
# SRCL    2142807000
# BXP     2135539000
# ISRG    2131700000
# ALLE    2118300000
# PKI     2105188000
# PG      2104745000
# REGN    2104745000
# AYI     2089100000
# EFX     2073000000
# Name: Total Revenue, dtype: int32

# %%
fund.isnull()
# Out:
#       Unnamed: 0  Ticker Symbol  Period Ending  Accounts Payable  \
# 0          False          False          False             False
# 1          False          False          False             False
# 2          False          False          False             False
# 3          False          False          False             False
# 4          False          False          False             False
# ...          ...            ...            ...               ...
# 1776       False          False          False             False
# 1777       False          False          False             False
# 1778       False          False          False             False
# 1779       False          False          False             False
# 1780       False          False          False             False
#
#       Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0                   False                       False          False
# ...

# %%
fund.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 79 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           1781 non-null   int64
#  1   Ticker Symbol                                        1781 non-null   object
#  2   Period Ending                                        1781 non-null   object
#  3   Accounts Payable                                     1781 non-null   float64
#  4   Accounts Receivable                                  1781 non-null   float64
#  5   Add'l income/expense items                           1781 non-null   float64
#  6   After Tax ROE                                        1781 non-null   float64
#  7   Capital Expenditures                                 1781 non-null   float64
# ...

# %%
fund.dropna()
# Out:
#       Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0              0           AAL    2012-12-31      3.068000e+09
# 1              1           AAL    2013-12-31      4.975000e+09
# 2              2           AAL    2014-12-31      4.668000e+09
# 3              3           AAL    2015-12-31      5.102000e+09
# 4              4           AAP    2012-12-29      2.409453e+09
# ...          ...           ...           ...               ...
# 1771        1771           ZBH    2014-12-31      2.255000e+08
# 1772        1772           ZBH    2015-12-31      4.320000e+08
# 1777        1777           ZTS    2013-12-31      1.381000e+09
# 1778        1778           ZTS    2014-12-31      1.071000e+09
# 1779        1779           ZTS    2015-12-31      1.313000e+09
#
#       Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0            -222000000.0               -1.961000e+09           23.0
# ...
